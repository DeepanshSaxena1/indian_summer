# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('indian_summer.csv')
df.head()
# Out:
#         City        Date  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  New Delhi  01-04-2021     34.0     19.0  27.1          31.6          19.0
# 1  New Delhi  02-04-2021     33.9     16.0  25.8          31.8          16.0
# 2  New Delhi  03-04-2021     34.8     14.6  26.0          32.2          14.6
# 3  New Delhi  04-04-2021     36.8     16.9  27.1          34.2          16.9
# 4  New Delhi  05-04-2021     38.8     21.0  29.9          37.1          21.0
#
#    feelslike  dew  humidity  windspeed  winddir  sealevelpressure  cloudcover  \
# 0       26.1  3.1     22.60       22.8    272.9            1002.8         0.0
# 1       24.9  4.5     27.62       12.4    275.0            1006.2         0.0
# 2       25.1  1.3     23.18       16.5    127.5            1008.8         1.4
# 3       26.0  4.8     28.00       18.3    157.6            1009.5         2.6
# 4       28.9  8.1     28.85       13.5    100.4            1007.8        38.4
#
# ...

# %%
df.shape
# Out:
# (13650, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13650 entries, 0 to 13649
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              13650 non-null  object
#  1   Date              13650 non-null  object
#  2   tempmax           13615 non-null  float64
#  3   tempmin           13615 non-null  float64
#  4   temp              13605 non-null  float64
#  5   feelslikemax      13614 non-null  float64
#  6   feelslikemin      13614 non-null  float64
#  7   feelslike         13604 non-null  float64
#  8   dew               13605 non-null  float64
#  9   humidity          13605 non-null  float64
#  10  windspeed         13605 non-null  float64
#  11  winddir           13600 non-null  float64
#  12  sealevelpressure  10631 non-null  float64
#  13  cloudcover        13605 non-null  float64
#  14  visibility        13605 non-null  float64
#  15  sunrise           13650 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['City', 'Date', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'sunrise', 'sunset',
#        'moonphase', 'conditions', 'description'],
#       dtype='object')

# %%
df.describe()
# Out:
#             tempmax       tempmin          temp  feelslikemax  feelslikemin  \
# count  13615.000000  13615.000000  13605.000000  13614.000000  13614.000000
# mean      36.728248     25.821160     31.151510     40.212605     27.221324
# std        4.115452      3.212167      3.074874      5.389016      4.907125
# min        0.000000      0.000000     19.900000      0.000000      0.000000
# 25%       34.000000     23.700000     29.200000     36.500000     23.700000
# 50%       37.000000     26.000000     31.100000     40.000000     26.000000
# 75%       39.800000     28.100000     33.200000     43.700000     31.100000
# max       50.000000     37.000000     40.500000     79.200000     43.300000
#
#           feelslike           dew      humidity     windspeed       winddir  \
# count  13604.000000  13605.000000  13605.000000  13605.000000  13600.000000
# mean      33.704535     19.049607     54.638537     20.078552    205.236559
# ...

# %%
df.isnull().sum()
# Out:
# City                   0
# Date                   0
# tempmax               35
# tempmin               35
# temp                  45
# feelslikemax          36
# feelslikemin          36
# feelslike             46
# dew                   45
# humidity              45
# windspeed             45
# winddir               50
# sealevelpressure    3019
# cloudcover            45
# visibility            45
# sunrise                0
# sunset                 0
# moonphase              0
# conditions            45
# description           45
# dtype: int64

# %%
df=df.drop(['sealevelpressure'],axis=1)

# %%
df.columns
# Out:
# Index(['City', 'Date', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'windspeed', 'winddir',
#        'cloudcover', 'visibility', 'sunrise', 'sunset', 'moonphase',
#        'conditions', 'description'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# City            0
# Date            0
# tempmax         0
# tempmin         0
# temp            0
# feelslikemax    0
# feelslikemin    0
# feelslike       0
# dew             0
# humidity        0
# windspeed       0
# winddir         0
# cloudcover      0
# visibility      0
# sunrise         0
# sunset          0
# moonphase       0
# conditions      0
# description     0
# dtype: int64

# %%
df.shape
# Out:
# (13599, 19)

# %%
df.conditions.unique()
# Out:
# array(['Clear', 'Partially cloudy', 'Rain, Partially cloudy',
#        'Rain, Overcast', 'Overcast', 'Rain'], dtype=object)

# %%
df.conditions.value_counts()
# Out:
# Partially cloudy          7852
# Clear                     3880
# Rain, Partially cloudy    1609
# Rain, Overcast             136
# Overcast                   113
# Rain                         9
# Name: conditions, dtype: int64

# %%
sns.countplot('conditions',data=df,palette='hls')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
count_clear= len(df[df.conditions=='Clear'])

# %%
count_clear
# Out:
# 3880

# %%
count_pcloudy=len(df[df.conditions=='Partially cloudy'])
count_pcloudy
# Out:
# 7852

# %%
count_rpcloudy=len(df[df.conditions=='Rain, Partially cloudy'])
count_rpcloudy
# Out:
# 1609

# %%
count_ro=len(df[df.conditions=='Rain, Overcast'])
count_ro
# Out:
# 136

# %%
count_overcast=len(df[df.conditions=='Overcast'])
count_ro
# Out:
# 136

# %%
count_rain=len(df[df.conditions=='Rain'])
count_rain
# Out:
# 9

# %%
print('Percentage of clear:{:2f}%'.format((count_clear/len(df.conditions))*100))
print('Percentage of pcloudy:{:2f}%'.format((count_pcloudy/len(df.conditions))*100))
print('Percentage of rpcloudy:{:2f}%'.format((count_rpcloudy/len(df.conditions))*100))
print('Percentage of ro:{:2f}%'.format((count_ro/len(df.conditions))*100))
print('Percentage of overcast:{:2f}%'.format((count_overcast/len(df.conditions))*100))
print('Percentage of rain:{:2f}%'.format((count_rain/len(df.conditions))*100))
# Out:
# Percentage of clear:28.531510%
# Percentage of pcloudy:57.739540%
# Percentage of rpcloudy:11.831752%
# Percentage of ro:1.000074%
# Percentage of overcast:0.830943%
# Percentage of rain:0.066181%

# %%
df[['humidity','tempmax','tempmin','windspeed']].describe()
# Out:
#            humidity       tempmax       tempmin     windspeed
# count  13599.000000  13599.000000  13599.000000  13599.000000
# mean      54.643784     36.756828     25.837937     20.083293
# std       19.519355      3.993890      3.133552      9.885514
# min        7.410000     19.900000     10.000000      0.000000
# 25%       38.195000     34.000000     23.700000     14.800000
# 50%       56.120000     37.000000     26.000000     19.500000
# 75%       71.420000     39.800000     28.100000     24.100000
# max       99.040000     50.000000     37.000000    263.200000

# %%
sns.set(style='darkgrid')
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=df,x='humidity',kde=True,ax=axs[0,0],color='green')
sns.histplot(data=df,x='tempmax',kde=True,ax=axs[0,1],color='red')
sns.histplot(data=df,x='tempmin',kde=True,ax=axs[1,0],color='skyblue')
sns.histplot(data=df,x='windspeed',kde=True,ax=axs[1,1],color='orange')
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='Count'>

# %%
sns.set(style='darkgrid')
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.violinplot(data=df,x='humidity',kde=True,ax=axs[0,0],color='green')
sns.violinplot(data=df,x='tempmax',kde=True,ax=axs[0,1],color='red')
sns.violinplot(data=df,x='tempmin',kde=True,ax=axs[1,0],color='skyblue')
sns.violinplot(data=df,x='windspeed',kde=True,ax=axs[1,1],color='orange')
# Out:
# <AxesSubplot:xlabel='windspeed'>

# %%
sns.boxplot('humidity','conditions',data=df,palette='YlOrBr')
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='humidity', ylabel='conditions'>

# %%
sns.boxplot('tempmax','conditions',data=df,palette='YlOrBr')
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tempmax', ylabel='conditions'>

# %%
sns.boxplot('tempmin','conditions',data=df,palette='YlOrBr')
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tempmin', ylabel='conditions'>

# %%
sns.boxplot('windspeed','conditions',data=df,palette='YlOrBr')
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='windspeed', ylabel='conditions'>

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
from scipy import stats
df.plot('humidity','tempmax',style='o')
print('pearson correlation: ',df['humidity'].corr(df['tempmax']))
print('T test and P value: ',stats.ttest_ind(df['humidity'],df['tempmax']))
# Out:
# pearson correlation:  -0.7241236608873358
# T test and P value:  Ttest_indResult(statistic=104.69321537002257, pvalue=0.0)

# %%
df.plot('windspeed','tempmax',style='o')
print('pearson correlation: ',df['windspeed'].corr(df['tempmax']))
print('T test and P value: ',stats.ttest_ind(df['windspeed'],df['tempmax']))
# Out:
# pearson correlation:  0.009607384829183973
# T test and P value:  Ttest_indResult(statistic=-182.368393165443, pvalue=0.0)

# %%
df.plot('tempmin','tempmax',style='o')
print('pearson correlation: ',df['tempmin'].corr(df['tempmax']))
print('T test and P value: ',stats.ttest_ind(df['tempmin'],df['tempmax']))
# Out:
# pearson correlation:  0.4102670197338058
# T test and P value:  Ttest_indResult(statistic=-250.82583693772827, pvalue=0.0)

# %%
df=df.drop(['Date','sunset','sunrise','description'],axis=1)

# %%
q1=df.quantile(0.25)
q3=df.quantile(0.75)
iqr=q3-q1
df=df[~((df<(q1-iqr*1.5))|(df>(q3+1.5*iqr))).any(axis=1)]

# %%
df.humidity=np.sqrt(df.humidity)
df.windspeed=np.sqrt(df.windspeed)

# %%
sns.set(style='darkgrid')
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=df,x='humidity',kde=True,ax=axs[0,0],color='green')
sns.histplot(data=df,x='tempmax',kde=True,ax=axs[0,1],color='red')
sns.histplot(data=df,x='tempmin',kde=True,ax=axs[1,0],color='skyblue')
sns.histplot(data=df,x='windspeed',kde=True,ax=axs[1,1],color='orange')
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='Count'>

# %%
df.head()
# Out:
#         City  tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike  \
# 0  New Delhi     34.0     19.0  27.1          31.6          19.0       26.1
# 4  New Delhi     38.8     21.0  29.9          37.1          21.0       28.9
# 5  New Delhi     38.0     22.6  30.4          37.2          22.6       29.5
# 6  New Delhi     36.0     23.4  29.6          34.6          23.4       28.7
# 7  New Delhi     34.9     20.9  27.6          32.6          20.9       26.7
#
#     dew  humidity  windspeed  winddir  cloudcover  visibility  moonphase  \
# 0   3.1  2.180354   2.185162    272.9         0.0         3.1       0.60
# 4   8.1  2.317589   1.916829    100.4        38.4         3.1       0.81
# 5  10.2  2.350231   1.961397    102.0        30.7         2.4       0.86
# 6   9.7  2.372633   2.071116    220.8        24.1         2.7       0.91
# 7   4.4  2.268237   1.996868    259.7         0.0         3.2       0.94
#
#          conditions
# 0             Clear
# 4  Partially cloudy
# ...

# %%
df1=df.drop(['City'],axis=1)

# %%
df1.head()
# Out:
#    tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0     34.0     19.0  27.1          31.6          19.0       26.1   3.1
# 4     38.8     21.0  29.9          37.1          21.0       28.9   8.1
# 5     38.0     22.6  30.4          37.2          22.6       29.5  10.2
# 6     36.0     23.4  29.6          34.6          23.4       28.7   9.7
# 7     34.9     20.9  27.6          32.6          20.9       26.7   4.4
#
#    humidity  windspeed  winddir  cloudcover  visibility  moonphase  \
# 0  2.180354   2.185162    272.9         0.0         3.1       0.60
# 4  2.317589   1.916829    100.4        38.4         3.1       0.81
# 5  2.350231   1.961397    102.0        30.7         2.4       0.86
# 6  2.372633   2.071116    220.8        24.1         2.7       0.91
# 7  2.268237   1.996868    259.7         0.0         3.2       0.94
#
#          conditions
# 0             Clear
# 4  Partially cloudy
# 5  Partially cloudy
# 6  Partially cloudy
# 7             Clear

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score , confusion_matrix, classification_report

# %%
le=LabelEncoder()

# %%
df1['conditions']=le.fit_transform(df1['conditions'])

# %%
df1.head()
# Out:
#    tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0     34.0     19.0  27.1          31.6          19.0       26.1   3.1
# 4     38.8     21.0  29.9          37.1          21.0       28.9   8.1
# 5     38.0     22.6  30.4          37.2          22.6       29.5  10.2
# 6     36.0     23.4  29.6          34.6          23.4       28.7   9.7
# 7     34.9     20.9  27.6          32.6          20.9       26.7   4.4
#
#    humidity  windspeed  winddir  cloudcover  visibility  moonphase  conditions
# 0  2.180354   2.185162    272.9         0.0         3.1       0.60           0
# 4  2.317589   1.916829    100.4        38.4         3.1       0.81           2
# 5  2.350231   1.961397    102.0        30.7         2.4       0.86           2
# 6  2.372633   2.071116    220.8        24.1         2.7       0.91           2
# 7  2.268237   1.996868    259.7         0.0         3.2       0.94           0

# %%
x=((df1.loc[:,df1.columns!='conditions']).astype(int)).values[:,0:]
y=df1['conditions'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
print('KNN Accuracy:{:2f}%'.format(knn.score(x_test,y_test)*100))
# Out:
# KNN Accuracy:85.967618%

# %%
svm=SVC()
svm.fit(x_train,y_train)
print('SVM Accuracy:{:2f}%'.format(svm.score(x_test,y_test)*100))
# Out:
# SVM Accuracy:86.507325%

# %%
gbc=GradientBoostingClassifier(subsample=0.5,n_estimators=450,max_depth=5,max_leaf_nodes=5)
gbc.fit(x_train,y_train)
print('Gradient Boosting Accuracy :{:2f}%'.format(gbc.score(x_test,y_test)*100))
# Out:
# Gradient Boosting Accuracy :89.205860%
